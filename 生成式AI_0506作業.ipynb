# %% [markdown]
# <a href="https://colab.research.google.com/github/david2003-bite-10-23/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_0506%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 情境:生成有趣小短片
# 內容:使用fooocus生成一個動漫角色逐漸變老的影片
#
# 模型參數:
# Sampling Steps:30
# Guidance Scale (CFG)：8.0
# Denoise Strength：0.4
# Performance:speed
# Upscale or Variation:Vary (Subtle)
# Image Number:3
# Aspect Ratio:1152×896
# 然後有input image所有的圖都是這一張圖生成出來的
# ![image.png](data:image/png;base64,...)
#
# 我使用以上參數為基礎，其餘參數都是預設的，配合上23個不同年紀的prompt來做生成，生成出逐漸變老的動漫角色，為了生成完整的影片所以我每一個prompt都生成3張圖，但是為了節省空間，以下我選擇五個no作為代表來展示(分別展示1、5、10、15，23)
#
# 以下是我的23個prompt(由gpt生成)
#
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  1  |  18 | `anime style portrait of elf girl, age 18, bright green eyes, perfectly smooth skin, soft lighting`                                                                                                 |
# |  2  |  21 | `anime style portrait of elf woman, age 21, youthful glow, barely visible smile lines, warm lighting`                                                                                               |
# |  3  |  24 | `anime style portrait of elf woman, age 24, faint laugh lines at eyes, fresh complexion, gentle smile`                                                                                              |
# |  4  |  27 | `anime style portrait of elf woman, age 27, subtle fine lines on forehead, confident gaze, soft background`                                                                                         |
# |  5  |  30 | `anime style portrait of elf woman, age 30, very slight crow’s feet, smooth cheeks, mature vibe`                                                                                                    |
# |  6  |  33 | `anime style portrait of elf woman, age 33, gentle smile wrinkles, defined cheekbones, calm expression`                                                                                             |
# |  7  |  36 | `anime style portrait of elf woman, age 36, light forehead creases, poised look, serene lighting`                                                                                                   |
# |  8  |  39 | `anime style portrait of elf woman, age 39, soft nasolabial folds, composed expression, natural tones`                                                                                              |
# |  9  |  42 | `anime style portrait of elf woman, age 42, subtle face creases, wise eyes, elegant posture`                                                                                                        |
# |  10 |  45 | `anime style portrait of elf woman, age 45, gentle deeper smile lines, graceful aura, muted color palette`                                                                                          |
# |  11 |  48 | `anime style portrait of elf woman, age 48, slight cheek sagging, dignified smile, soft shadows`                                                                                                    |
# |  12 |  51 | `anime style portrait of elf elder, age 51, noticeable wrinkles, seasoned look, warm ambient light`                                                                                                 |
# |  13 |  54 | `anime style portrait of elf elder, age 54, silver hair highlights, deeper crow’s feet, calm dignity`                                                                                               |
# |  14 |  57 | `anime style portrait of elf elder, age 57, pronounced laugh lines, wise eyes, soft pastel background`                                                                                              |
# |  15 |  60 | `anime style portrait of elf elder, age 60, silver hair streaks, aged skin texture, reflective expression`                                                                                          |
# |  16 |  63 | `anime style portrait of elf elder, age 63, age spots on cheeks, deeper forehead wrinkles, tranquil gaze`                                                                                           |
# |  17 |  66 | `anime style portrait of elf elder, age 66, sagging jawline, thoughtful expression, muted highlights`                                                                                               |
# |  18 |  69 | `anime style portrait of elf elder, age 69, pronounced wrinkles around eyes and mouth, gentle smile, soft focus`                                                                                    |
# |  19 |  72 | `anime style portrait of elf matriarch, age 72, deep wrinkles, serene gaze, dignified bearing`                                                                                                      |
# |  20 |  75 | `anime style portrait of elf matriarch, age 75, deep wrinkles, age spots, wise expression, soft twilight lighting`                                                                                  |
# |  21 |  80 | `anime style portrait of elf elder, age 80, deep crow’s feet and forehead wrinkles, sagging cheeks, thinning silver hair, age spots, solemn and venerable expression, soft twilight lighting`       |
# |  22 |  90 | `anime style portrait of ancient elf, age 90, pronounced facial wrinkles and sagging jawline, faded white hair streaks, prominent age spots, frail posture, mystical aura`                          |
# |  23 | 100 | `anime style portrait of ancestral elf matriarch, age 100, extreme deep-set wrinkles, drooping eyelids, mottled aged skin texture, wispy hair, wise and ethereal expression, ambient soft lighting` |

# %% [markdown]
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  1  |  18 | `anime style portrait of elf girl, age 18, bright green eyes, perfectly smooth skin, soft lighting`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  5  |  30 | `anime style portrait of elf woman, age 30, very slight crow’s feet, smooth cheeks, mature vibe`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  10  |  45 | `anime style portrait of elf woman, age 45, gentle deeper smile lines, graceful aura, muted color palette`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  15  |  60 | `anime style portrait of elf elder, age 60, silver hair streaks, aged skin texture, reflective expression`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | No. |  年齡 | Prompt                                                                                                                                                                                              |
# | :-: | :-: | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# |  23  |  100 | `anime style portrait of ancestral elf matriarch, age 100, extreme deep-set wrinkles, drooping eyelids, mottled aged skin texture, wispy hair, wise and ethereal expression, ambient soft lighting`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 成果展示
# 影片的網址:https://github.com/david2003-bite-10-23/generative_ai/blob/d0d20dae171effa9b456a8275d5753aca4817d31/output.mp4
#
# (在github裡面的output.mp4)

# %% [markdown]
# ### 心得:
# ### 整體來說我主要是用輕微改變的功能讓他能夠看起來有前後連貫性，但是也是因為他 改變的幅度小所以雖然保有連貫性了，但是做出來的圖也都差不多，我在想是不是因為prompt對具體的數字年齡比較沒有感覺，所以比較難做出逐漸變老的感覺，但是經過這一次的試驗，我認為要利用foocus做短影音是可能只是需要花比較多的時間重複嘗試功能
