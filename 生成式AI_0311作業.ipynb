# %% [markdown]
# <a href="https://colab.research.google.com/github/david2003-bite-10-23/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_0311%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 這一周的作業我主要是比較gemini以及gpt-4o

# %% [markdown]
# ----------------------------------------------------------------------------
# ### 問題一:有一個攤販賣花枝丸一串30塊錢，我有100塊錢，有甚麼方法可以買到最多的花枝丸，可以給我一些創新的想法嗎?

# %% [markdown]
# ### **gemini**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **gpt-4o**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ------------------------------------------------------------------------------
# ###問題二:請構思一個以未來科技與人性議題為主題的短篇小說開頭。要求描述一個未來世界，其中人工智能與人類生活緊密結合，並必須融入至少三項具體的科技元素（例如虛擬實境、腦機介面、量子運算等）。此外，請著重描述該世界中出現的某個衝突或挑戰，讓讀者能感受到人類與技術間的微妙平衡與矛盾。

# %% [markdown]
# ### **gemini**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **gpt-4o**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 問題三:假設你負責設計一個自動駕駛車的決策系統，當車輛遇到緊急情況時，必須在兩種風險中做出選擇：
#
# ###一是優先保護車內乘客，但可能造成外部行人受傷；
#
# ###二是優先保護外部行人，但可能導致車內乘客受到傷害。
# ###請詳細描述你如何設計這個決策算法，並論述在技術實現與倫理考量上可能面臨的挑戰與權衡，說明你如何在安全性、公平性與法律規範間取得平衡。       給我簡潔的回答

# %% [markdown]
# ### **gemini**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **gpt-4o**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##評估
# ###第一題整題來說不相上下，gemini的回答更加有趣但是gpt的回答更加有可行性，這一個問題本身沒有對錯，目前可以看出兩個語言模型理解問題的方向不同。
# ###第二題:兩個模型都沒有離題，但是我個人私心喜歡gpt的回答，整體來說昨為讀者我更喜歡gpt的回答，他使用了更多現代人撰寫小說的手法(至少我自己感覺gpt寫的比較像是小說gemini比較像是小學生寫的作文)，所以在這一方面我認為gpt是明顯勝出的
# ###第三題:我認為在這一題中兩者差距較小也都有回達到問題，但如果以審視計畫書的立場我認為gpt在實用性上更勝一籌，他確實點出了重要的問題點並且說出了他對於問題的看法，雖然gemini也有點出問題，但是在我看來胎只有點出問題本身並沒有太多的深入點，我個人主觀地認為這兩份計畫書gpt的計畫書是較為優秀的
#
# ###整體看來我認為gpt的模型在描述細節上是較為優秀的，相對來說gemini雖然細節方面以及深度方面並沒有gpt那麼優秀但是卻也不差了，他也是可以給出許多有趣且不錯的回答的。我覺得兩個模型各有優缺，風格上也有所不同，但是基於這一次的測試來說的話我應該會更喜歡使用gpt一些。
