# %% [markdown]
# <a href="https://colab.research.google.com/github/david2003-bite-10-23/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_0218%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 畫會動的數線 sin(x)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from matplotlib import patheffects

# %%
fig, ax = plt.subplots()
ax.set_xlim(0, 4 * np.pi)
ax.set_ylim(-1.5, 1.5)


xlabel_text = ax.set_xlabel("This is a \"moving\" sin()", fontsize=16, color="green", fontweight="bold")

pe = [patheffects.withStroke(linewidth=2, foreground="black")]
xlabel_text.set_path_effects(pe)

x = np.linspace(0, 4 * np.pi, 1000)
line, = ax.plot(x, np.sin(x), lw=2)

def animate(i):
    phase = i * 0.1
    y = np.sin(x - phase)
    line.set_data(x, y)
    return line,


ani = FuncAnimation(fig, animate, frames=200, interval=50, blit=True)


HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# [我與gpt的對話過程](https://chatgpt.com/share/67bb7679-a744-8010-8063-a3be81fb55e5)
#
# 內容簡單講解:
# 最一開始覺得數線太無聊，想要改寫一個會動的sin()，第一次生成的時候語法錯了，但是第二次生成有成功，但是我卻發現他跟我想得不太一樣，我想要做的是一個往前的sin()，但是他卻給我一個模擬sin()擺動的紅點，所以午又請他生成第三次最終他生成成功了，他使用matplot生成的數線圖一起合成一個影像串流來達成甚麼要求
#
# 從此次範例中我學到的是生成式AI不太有辦法一步到位，但是他可以逐漸修正進而得到自己想要的東西

# %% [markdown]
# 以下是我的生成結果，他好像沒辦法直接在github跑出來，建議老師可以執行一下
