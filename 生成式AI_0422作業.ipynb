# %% [markdown]
# <a href="https://colab.research.google.com/github/david2003-bite-10-23/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_0422%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 風格:日式動漫風格
# 以下是四張用同一個風格不同的prompt生成的圖(生成自copilot的microsoft bing模型)

# %% [markdown]
# ###prompt:櫻花少女
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###prompt:西方龍
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###prompt:東方龍
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###prompt:武士
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 我認為我最喜歡第一張圖，第二張圖以及第三張圖，我的要求是東方龍以及西方龍但是他並沒有區分出來，第四張圖則是太過寫實，我認為他沒有充分表達出動漫的元素，第一張則是很好的演示出了動漫風格所以我最喜歡第一張圖
